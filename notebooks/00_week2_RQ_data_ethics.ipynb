# %% [markdown]
# # Research Question, Dataset, and Ethics Check
#
# Use this notebook to document three things for your proposed research project:
#
# 1. Your research question
# 2. The dataset you plan to use
# 3. The ethical aspects you have considered
#
# > Do not load or analyse the data in this notebook. Choose a dataset, provide a reliable reference link, explain why you chose it, and answer the ethics questions using the dataset documentation and any relevant research literature. If a question is not applicable, write N/A and explain why.
#
# ## 1. Research Question
#
# - **Main research question:** What impacts student dropout more: financial pressure (like tuition debt or lack of a scholarship) or academic performance?"
# - **Why is this question interesting or important?** he topic is both important in generak due to the state of the country at the minute, and important for universities to understand the impacts there can be on students' lives so they can better support these students
# - **Who might use or care about the answer?** Students, Universities, and parents could use the data
# - **Possible sub-questions:** n/a
#
# ## 2. Dataset Reference
#
# - **Dataset name:** Predict students' dropout and academic success
# - **Source link:** (https://www.kaggle.com/datasets/thedevastator/higher-education-predictors-of-student-retention/data)
# - **Date accessed:** 2026-09-14
# - **Who published or collected it?** unknown
# - **Why did you choose this dataset?**We felt that lack of wealth played a great role in the number of students not finishing university, and felt it topical with the current cost of living crisis
# - **Evidence or notes:** n/a

# %% [markdown]
# ## Research Questions and Answers
#
# For every answer, distinguish between **known evidence**, **reasonable interpretation**, and **unknown information to investigate**.
#
# ### 1. Where did the data come from?
#
# **Answer:** [a group of students from a unnamed university.]
#
# ### 2. Why was it originally collected?
#
# **Answer:** [find the effect of the many collected datapoints on a students completion of university course.]
#
# ### 3. Who is represented?
#
# **Answer:** [university students from a variety of financial backrounds.]
#
# ### 4. Who might be missing?
#
# **Answer:** [there is no obvious missing groups in the data]
#
# ### 5. What personal or sensitive information does it contain, explicitly or implicitly?
#
# **Answer:** [it contains no personal or sensitive infrormantion]
#
# ### 6. What could your analysis reveal that was not obvious in the original data?
#
# **Answer:** [.the difference in effect of financial and academic stress on students]
#
# ### 7. Who could benefit from your findings?
#
# **Answer:** [clearly identify the depth of the affect of poverty/wealth and/ or grades on course completion]
#
# ### 8. Who could be harmed or misrepresented?
#
# **Answer:** [i dont feel that any group is misrepresented or harmed.]
